# %% [markdown]
# # GitHub Jupyter Notebook 預覽測試
#
# 這是我們在這個教學專案中示範的 Python 與資料科學筆記本！
# 在這裡，您可以發現 GitHub 原生支援閱讀 Jupyter Notebook，完美渲染了原始的 Markdown、程式碼和輸出結果。

# %%
print("哈囉，GitHub！這是一段簡單的 Python 程式。")
print("這是我計算的乘法表：")
print(f"9 x 9 = {9 * 9}")
# Out:
# 哈囉，GitHub！這是一段簡單的 Python 程式。
# 這是我計算的乘法表：
# 9 x 9 = 81
